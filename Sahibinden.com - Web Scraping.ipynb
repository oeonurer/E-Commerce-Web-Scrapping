# %%
from selenium import webdriver
from time import sleep
# Data manipulation
import pandas as pd
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC



driver = webdriver.Chrome(executable_path="C:/Users/ONUR/Desktop/chromedriver.exe")
migros_arama = "hyundai getz"

driver.get("https://www.sahibinden.com/")
sleep(4)



#arama
driver.find_element_by_xpath('//*[@id="searchText"]')\
    .send_keys(migros_arama)
driver.find_element_by_xpath('//*[@id="searchSuggestionForm"]/button')\
    .click()
sleep(3)

#çerezleri kabul etme
driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]')\
    .click()
sleep(3)


driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))

sleep(3)
    
    
item_titles = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[2]')
item_prices = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[3]')
item_loca = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[5]')
item_date = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[4]')


# boş liste
titles_list = []
prices_list = []
loca_list = []
date_list = []

# Loop over the item_titles and item_prices
for title in item_titles:
    titles_list.append(title.text)
for prices in item_prices:
    prices_list.append(prices.text)
for locat in item_loca:
    loca_list.append(locat.text)
for dat in item_date:
    date_list.append(dat.text)




print(titles_list)
print(prices_list)
print(loca_list)
print(date_list)

driver.close()
# Out:
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/ONUR/Desktop/chromedriver.exe")
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="searchText"]')\
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="searchSuggestionForm"]/button')\
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//*[@id="onetrust-accept-btn-handler"]')\
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   item_titles = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[2]')
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:41: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   item_prices = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[3]')
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   item_loca = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[5]')
# C:\Users\ONUR\AppData\Local\Temp/ipykernel_2880/1540229288.py:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   item_date = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[4]')
# ['HATASIZ.. 2008 Model Hyundai Getz 1.4 Dohc Benzin&LPG 159.000km', '2010 Hyundai Getz 1.4 Otomatik 75.000km', 'Temiz aile aracı', '106800km de 2011 model temiz', 'HYUNDAİ GETZ 2007 MODEL 1.4 DOHC HY KLM', '2010 MODEL 1.5 DİZEL GETZ', 'SADECE 2.5 PARÇA BOYALI HARİCİ HATASIZ', 'Sahibinden acil satılık Getz 169.xxx', 'Masrafsız temiz araç', 'Sahibinden Temiz, hasarsız, değişensiz araç', '2005_Hyudai_Getz_1.3\xad_Gls_Çift_Airbag_Ab\xads_Klima_Yeni_Muayne_', 'İLK SAHİBİNDEN SUNROOFLU HATASIZ DÜŞÜK KM. 2006 HYUNDAİ GETZ', 'klimalı temiz ve bakimli', 'EMSALSİZ TERTEMİZ HYUNDAİ GETZ', 'Sahibinden temiz bakımlı Hyundai Gets', '2008 HATASİZ SERVİS BAKIMLI ABS KLİMA ELEKTRİKLİ AYNA FULL GEZT', 'Memurdan Temiz, Diri , Getz', "KÖMBECİ'DEN HYUNDAİ GETZ 110 HP 4 SİLİNDİR TUTULAN MODEL BAKIMLI", "SEVİNÇLER OTO'DAN HATASIZ BOYASIZ DEĞİŞENSİZ 4 SİLİNDİR....", '***2007*** TERTEMİZ HYUNDAİ GETZ 1.4 CRDİ 110 BG / VGT STARD', 'YAĞMUR OTOMOTİVDEN HATASIZ 1.5 DİZEL KLİMALI VGT GETZ 190.000 KM', 'HATASIZ CAM GİBİ...', '2008 MODEL 1.5 DİZEL 110 LUK MASRAFSIZ', '2005 MODEL ÇİFT AİRBAĞ ABS Lİ KLİMALI 113.200 KİLOMETRDE', '2009*1.4 HATASIZ BOYASIZ', "2004 HYUNDAİ GETZ 1.3 GLS KLİMA'LI 4 CAM OTOMATİK LPG KIRMIZI", 'Getz Cool Acil ev almak için satıyorum', '2011+GETZ+1.5 CRDİ+BOYASIZ+H\xadATASIZ+EZİKSİZ +104.000 KM DE', 'Degisensiz boyasiz 109 bin km de', 'Hyundai getz düşük km aile aracı', "Burak Otomotiv'den 2006 Hyundai Getz 1.5 CRDİ ABS_KLİMA", 'SAHİBİNDEN TEMİZ HATASIZ 1.5 GETZ', '64BINDE OTOMATIK HYUNDAI GETZ 1.4 DOHC', "GALERİ ERSOY'DAN GETZ DİZEL SADECE 88 BİN KM DE, DEĞİŞENSİZ...", 'ÖZGÜR 62 DEN OTOMATİK GEST', 'Getz 94.000 KM İlk Sahibinden alınma.Otomatik Takaslı.Aile Aracı', 'getz in en çok tutulan modeli 1.4 doch motor', 'Hyundai getz 1.5CRDİ VGT', 'sahibinden temiz getz', 'ÖGRETMENDEN HYUNDAI GETZ 2009 OTOMATIK 134000KM', 'Doktordan Temiz Bakımlı Getz', "DÜŞGÜN OTOMOTİV'DEN HYUNDAİ GETZ 2010 MODELDÜŞGÜN OTOMOTİV TÜM", 'MASRAFSIZ MUAYNE YENİ', 'OTTOM OTOMOTİVDEN HUYUNDAİ GETZ 1.5 DİZEL KLİMALI', 'ÇOK TEMİZ DİZEL MASRAFSIZ', 'aracım güzeldir aracıma kefilim araç yükseltmek için satıyorum', "ERC AUTO'DAN DÜŞÜK KİLOMETRE BAKIMLI GARAJ ARABASI TERTEMİZ", 'HATASIZ BOYASIZ', '2009 MODEL 84.000 KM OTOMATİK HYUNDAİ GETZ 1.4 DOCH', '2010 HYUNDAİ GETZ 1.4 DOHC START KLİMALI']
# ['167.000 TL', '216.000 TL', '198.000 TL', '168.500 TL', '122.000 TL', '155.250 TL', '155.000 TL', '137.000 TL', '163.000 TL', '175.000 TL', '167.000 TL', '172.000 TL', '122.000 TL', '165.500 TL', '135.000 TL', '227.000 TL', '150.000 TL', '145.000 TL', '150.000 TL', '132.000 TL', '177.500 TL', '172.500 TL', '138.000 TL', '152.500 TL', '172.500 TL', '132.500 TL', '135.000 TL', '213.000 TL', '168.500 TL', '150.000 TL', '128.000 TL', '172.000 TL', '235.000 TL', '168.500 TL', '145.000 TL', '137.000 TL', '122.000 TL', '135.000 TL', '135.000 TL', '194.000 TL', '217.000 TL', '132.900 TL', '142.500 TL', '127.500 TL', '135.000 TL', '144.000 TL', '149.750 TL', '172.500 TL', '189.500 TL', '179.500 TL']
# ['Çanakkale\nAyvacık', 'İstanbul\nÜsküdar', 'İzmir\nBuca', 'Aydın\nEfeler', 'Gaziantep\nŞahinbey', 'Kocaeli\nGebze', 'Hatay\nAntakya', 'İstanbul\nKüçükçekmece', 'Tekirdağ\nÇerkezköy', 'Giresun\nMerkez', 'Çorum\nMerkez', 'Muğla\nFethiye', 'Bursa\nOsmangazi', 'Kocaeli\nDerince', 'Zonguldak\nMerkez', 'Ankara\nÇankaya', 'Bolu\nMerkez', 'Karaman\nMerkez', 'Samsun\nBafra', 'Antalya\nKepez', 'Eskişehir\nOdunpazarı', 'Adıyaman\nMerkez', 'Eskişehir\nTepebaşı', 'Manisa\nAkhisar', 'Osmaniye\nMerkez', 'Osmaniye\nMerkez', 'İstanbul\nGüngören', 'Tokat\nTurhal', 'İzmir\nBuca', 'Bursa\nYıldırım', 'Konya\nKaratay', 'Antalya\nKepez', 'İstanbul\nBeykoz', 'İstanbul\nSancaktepe', 'Elazığ\nMerkez', 'İstanbul\nPendik', 'Adana\nYüreğir', 'Gümüşhane\nMerkez', 'İzmir\nÇiğli', 'Düzce\nMerkez', 'İstanbul\nSarıyer', 'Adana\nSeyhan', 'Mersin\nErdemli', 'Sakarya\nAdapazarı', 'Diyarbakır\nBağlar', 'Diyarbakır\nKocaköy', 'Mersin\nToroslar', 'Sakarya\nErenler', 'İstanbul\nKadıköy', 'Erzurum\nYakutiye']
# ['21 Mayıs\n2022', '17 Mayıs\n2022', '22 Mayıs\n2022', '22 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022', '21 Mayıs\n2022']

# %%
dfS = pd.DataFrame(zip(titles_list, prices_list, loca_list, date_list), columns=['İlan Başlığı', 'Fiyat', 'Lokasyon', 'Tarih'])

# %%
dfS['Fiyat'] = dfS['Fiyat'].str.replace('TL', '').astype(float)

# %%
dfS
# Out:
#                                          İlan Başlığı   Fiyat  \
# 0   HATASIZ.. 2008 Model Hyundai Getz 1.4 Dohc Ben...  167.00
# 1             2010 Hyundai Getz 1.4 Otomatik 75.000km  216.00
# 2                                    Temiz aile aracı  198.00
# 3                        106800km de 2011 model temiz  168.50
# 4             HYUNDAİ GETZ 2007 MODEL 1.4 DOHC HY KLM  122.00
# 5                           2010 MODEL 1.5 DİZEL GETZ  155.25
# 6              SADECE 2.5 PARÇA BOYALI HARİCİ HATASIZ  155.00
# 7                Sahibinden acil satılık Getz 169.xxx  137.00
# 8                                Masrafsız temiz araç  163.00
# 9         Sahibinden Temiz, hasarsız, değişensiz araç  175.00
# 10  2005_Hyudai_Getz_1.3­_Gls_Çift_Airbag_Ab­s_Kli...  167.00
# 11  İLK SAHİBİNDEN SUNROOFLU HATASIZ DÜŞÜK KM. 200...  172.00
# 12                           klimalı temiz ve bakimli  122.00
# 13                     EMSALSİZ TERTEMİZ HYUNDAİ GETZ  165.50
# 14              Sahibinden temiz bakımlı Hyundai Gets  135.00
# 15  2008 HATASİZ SERVİS BAKIMLI ABS KLİMA ELEKTRİK...  227.00
# 16                        Memurdan Temiz, Diri , Getz  150.00
# 17  KÖMBECİ'DEN HYUNDAİ GETZ 110 HP 4 SİLİNDİR TUT...  145.00
# 18  SEVİNÇLER OTO'DAN HATASIZ BOYASIZ DEĞİŞENSİZ 4...  150.00
# 19  ***2007*** TERTEMİZ HYUNDAİ GETZ 1.4 CRDİ 110 ...  132.00
# 20  YAĞMUR OTOMOTİVDEN HATASIZ 1.5 DİZEL KLİMALI V...  177.50
# 21                                HATASIZ CAM GİBİ...  172.50
# 22             2008 MODEL 1.5 DİZEL 110 LUK MASRAFSIZ  138.00
# 23  2005 MODEL ÇİFT AİRBAĞ ABS Lİ KLİMALI 113.200 ...  152.50
# 24                           2009*1.4 HATASIZ BOYASIZ  172.50
# 25  2004 HYUNDAİ GETZ 1.3 GLS KLİMA'LI 4 CAM OTOMA...  132.50
# 26             Getz Cool Acil ev almak için satıyorum  135.00
# 27  2011+GETZ+1.5 CRDİ+BOYASIZ+H­ATASIZ+EZİKSİZ +1...  213.00
# 28                   Degisensiz boyasiz 109 bin km de  168.50
# 29                   Hyundai getz düşük km aile aracı  150.00
# 30  Burak Otomotiv'den 2006 Hyundai Getz 1.5 CRDİ ...  128.00
# 31                  SAHİBİNDEN TEMİZ HATASIZ 1.5 GETZ  172.00
# 32             64BINDE OTOMATIK HYUNDAI GETZ 1.4 DOHC  235.00
# 33  GALERİ ERSOY'DAN GETZ DİZEL SADECE 88 BİN KM D...  168.50
# 34                         ÖZGÜR 62 DEN OTOMATİK GEST  145.00
# 35  Getz 94.000 KM İlk Sahibinden alınma.Otomatik ...  137.00
# 36       getz in en çok tutulan modeli 1.4 doch motor  122.00
# 37                           Hyundai getz 1.5CRDİ VGT  135.00
# 38                              sahibinden temiz getz  135.00
# 39    ÖGRETMENDEN HYUNDAI GETZ 2009 OTOMATIK 134000KM  194.00
# 40                       Doktordan Temiz Bakımlı Getz  217.00
# 41  DÜŞGÜN OTOMOTİV'DEN HYUNDAİ GETZ 2010 MODELDÜŞ...  132.90
# 42                              MASRAFSIZ MUAYNE YENİ  142.50
# 43  OTTOM OTOMOTİVDEN HUYUNDAİ GETZ 1.5 DİZEL KLİMALI  127.50
# 44                          ÇOK TEMİZ DİZEL MASRAFSIZ  135.00
# 45  aracım güzeldir aracıma kefilim araç yükseltme...  144.00
# 46  ERC AUTO'DAN DÜŞÜK KİLOMETRE BAKIMLI GARAJ ARA...  149.75
# 47                                    HATASIZ BOYASIZ  172.50
# 48  2009 MODEL 84.000 KM OTOMATİK HYUNDAİ GETZ 1.4...  189.50
# 49           2010 HYUNDAİ GETZ 1.4 DOHC START KLİMALI  179.50
#
#                   Lokasyon           Tarih
# 0       Çanakkale\nAyvacık  21 Mayıs\n2022
# 1        İstanbul\nÜsküdar  17 Mayıs\n2022
# 2              İzmir\nBuca  22 Mayıs\n2022
# 3            Aydın\nEfeler  22 Mayıs\n2022
# 4      Gaziantep\nŞahinbey  21 Mayıs\n2022
# 5           Kocaeli\nGebze  21 Mayıs\n2022
# 6           Hatay\nAntakya  21 Mayıs\n2022
# 7   İstanbul\nKüçükçekmece  21 Mayıs\n2022
# 8      Tekirdağ\nÇerkezköy  21 Mayıs\n2022
# 9          Giresun\nMerkez  21 Mayıs\n2022
# 10           Çorum\nMerkez  21 Mayıs\n2022
# 11          Muğla\nFethiye  21 Mayıs\n2022
# 12        Bursa\nOsmangazi  21 Mayıs\n2022
# 13        Kocaeli\nDerince  21 Mayıs\n2022
# 14       Zonguldak\nMerkez  21 Mayıs\n2022
# 15         Ankara\nÇankaya  21 Mayıs\n2022
# 16            Bolu\nMerkez  21 Mayıs\n2022
# 17         Karaman\nMerkez  21 Mayıs\n2022
# 18           Samsun\nBafra  21 Mayıs\n2022
# 19          Antalya\nKepez  21 Mayıs\n2022
# 20   Eskişehir\nOdunpazarı  21 Mayıs\n2022
# 21        Adıyaman\nMerkez  21 Mayıs\n2022
# 22     Eskişehir\nTepebaşı  21 Mayıs\n2022
# 23         Manisa\nAkhisar  21 Mayıs\n2022
# 24        Osmaniye\nMerkez  21 Mayıs\n2022
# 25        Osmaniye\nMerkez  21 Mayıs\n2022
# 26      İstanbul\nGüngören  21 Mayıs\n2022
# 27           Tokat\nTurhal  21 Mayıs\n2022
# 28             İzmir\nBuca  21 Mayıs\n2022
# 29         Bursa\nYıldırım  21 Mayıs\n2022
# 30          Konya\nKaratay  21 Mayıs\n2022
# 31          Antalya\nKepez  21 Mayıs\n2022
# 32        İstanbul\nBeykoz  21 Mayıs\n2022
# 33    İstanbul\nSancaktepe  21 Mayıs\n2022
# 34          Elazığ\nMerkez  21 Mayıs\n2022
# 35        İstanbul\nPendik  21 Mayıs\n2022
# 36          Adana\nYüreğir  21 Mayıs\n2022
# 37       Gümüşhane\nMerkez  21 Mayıs\n2022
# 38            İzmir\nÇiğli  21 Mayıs\n2022
# 39           Düzce\nMerkez  21 Mayıs\n2022
# 40       İstanbul\nSarıyer  21 Mayıs\n2022
# 41           Adana\nSeyhan  21 Mayıs\n2022
# 42         Mersin\nErdemli  21 Mayıs\n2022
# 43      Sakarya\nAdapazarı  21 Mayıs\n2022
# 44      Diyarbakır\nBağlar  21 Mayıs\n2022
# 45     Diyarbakır\nKocaköy  21 Mayıs\n2022
# 46        Mersin\nToroslar  21 Mayıs\n2022
# 47        Sakarya\nErenler  21 Mayıs\n2022
# 48       İstanbul\nKadıköy  21 Mayıs\n2022
# 49       Erzurum\nYakutiye  21 Mayıs\n2022

# %%
print(dfS["Fiyat"].median())
# Out:
# 153.75

# %%
print(dfS["Fiyat"].mean())
# Out:
# 159.918

# %%
print(dfS["Fiyat"].min())
# Out:
# 122.0

# %%
print(dfS["Fiyat"].max())
# Out:
# 235.0

# %%
print(dfS["Fiyat"].describe())
# Out:
# count     50.000000
# mean     159.918000
# std       28.455192
# min      122.000000
# 25%      135.500000
# 50%      153.750000
# 75%      172.500000
# max      235.000000
# Name: Fiyat, dtype: float64
